# %% [markdown]
# ### Working with Merged County Data

# %%
# Import dependencies
import pandas as pd
import numpy as np
import scipy.stats as st
import sklearn as sk

# %%
# Primary file -- merged_county_data
infile = 'Source_Data/merged2_county_data.csv'
cnty_df = pd.read_csv(infile)
cnty_df.head()
# Out:
#    Unnamed: 0   county    state  county_and_state_x    code  Deaths  \
# 0           0  Autauga  Alabama  Autauga County, AL  1001.0   163.0
# 1           1  Baldwin  Alabama  Baldwin County, AL  1003.0   640.0
# 2           2  Barbour  Alabama  Barbour County, AL  1005.0    90.0
# 3           3     Bibb  Alabama     Bibb County, AL  1007.0    79.0
# 4           4   Blount  Alabama   Blount County, AL  1009.0   199.0
#
#    Population Crude Rate    fips  smoking  ...    noinsurance  physicians  \
# 0     55416.0      294.1  1001.0     19.0  ...            9.0        42.0
# 1    208563.0      306.9  1003.0     17.0  ...           11.0        73.0
# 2     25965.0      346.6  1005.0     22.0  ...           13.0        39.0
# 3     22643.0      348.9  1007.0     20.0  ...           10.0        57.0
# 4     57704.0      344.9  1009.0     20.0  ...           12.0        23.0
#
#    pollution  diabetes  county_and_state_y   code2  sunlight   blow   ganj  \
# 0       11.7      14.0  Autauga County, AL  1001.0  17103.72  1.158  9.282
# 1       10.3      11.0  Baldwin County, AL  1003.0  17660.59  1.158  9.282
# 2       11.5      18.0  Barbour County, AL  1005.0  17315.13  1.158  9.282
# 3       11.2      15.0     Bibb County, AL  1007.0  16904.87  1.158  9.282
# 4       11.7      14.0   Blount County, AL  1009.0  16393.63  1.158  9.282
#
#    smack
# 0  0.276
# 1  0.276
# 2  0.276
# 3  0.276
# 4  0.276
#
# [5 rows x 23 columns]

# %%
# Let's check out how 'full' the data set is...
fill = pd.DataFrame({'Entries':cnty_df.count(),'Unique Items':cnty_df.nunique()})
fill
# Out:
#                     Entries  Unique Items
# Unnamed: 0             3252          3252
# county                 3189          1877
# state                  3244            56
# county_and_state_x     2968          2968
# code                   2968          2968
# Deaths                 2968           725
# Population             2968          2915
# Crude Rate             2968          2186
# fips                   3197          3191
# smoking                3197            33
# obesity                3197            35
# foodenv                3178            84
# exercise               3191           101
# noinsurance            3196            31
# physicians             3061           176
# pollution              3161           113
# diabetes               2296            19
# county_and_state_y     3117          3111
# code2                  3117          3111
# sunlight               3117          3103
# blow                   3244            56
# ganj                   3244            54
# smack                  3244            55

# %% [markdown]
# * 3257 rows is more than any one item's count, so we didn't lose anything, but there were imperfect mergers.
# * There are 3194 entries for county, and 56 for state.  Let's look at the state names:

# %%
cnty_df.state.value_counts(dropna=False)
# Out:
# Texas                   255
# Virginia                171
# Georgia                 160
# Kentucky                121
# Missouri                117
# Kansas                  106
# Illinois                103
# North Carolina          101
# Iowa                    100
# Tennessee                96
# Indiana                  96
# Nebraska                 94
# Ohio                     89
# Minnesota                88
# Michigan                 84
# Mississippi              83
# Oklahoma                 78
# Arkansas                 76
# Wisconsin                73
# Pennsylvania             69
# Alabama                  68
# South Dakota             68
# Florida                  68
# Louisiana                66
# Colorado                 65
# New York                 63
# California               59
# Montana                  57
# West Virginia            56
# North Dakota             54
# South Carolina           47
# Idaho                    45
# Washington               40
# Oregon                   37
# New Mexico               34
# Alaska                   31
# Utah                     30
# Maryland                 26
# Wyoming                  24
# New Jersey               22
# Nevada                   19
# Maine                    17
# Arizona                  16
# Massachusetts            15
# Vermont                  15
# New Hampshire            11
# Connecticut               9
# NaN                       8
# Hawaii                    6
# Rhode Island              6
# Delaware                  4
# Midwest                   1
# South                     1
# Total United States       1
# District of Columbia      1
# West                      1
# Northeast                 1
# Name: state, dtype: int64

# %% [markdown]
# * Just 8 rows where we are missing a state.  Let's look at those:

# %%
nostate = cnty_df.loc[cnty_df.state.isnull(),:]
nostate
# Out:
#      Unnamed: 0                    county state        county_and_state_x  \
# 99           99  District of Columbia, DC   NaN  District of Columbia, DC
# 100         100                       NaN   NaN                       NaN
# 101         101                       NaN   NaN                       NaN
# 102         102                       NaN   NaN                       NaN
# 103         103                       NaN   NaN                       NaN
# 104         104                       NaN   NaN                       NaN
# 105         105                       NaN   NaN                       NaN
# 106         106                       NaN   NaN                       NaN
#
#         code  Deaths  Population Crude Rate  fips  smoking  ...    \
# 99   11001.0  1752.0    681170.0      257.2   NaN      NaN  ...
# 100      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 101      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 102      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 103      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 104      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 105      NaN     NaN         NaN        NaN   NaN      NaN  ...
# 106      NaN     NaN         NaN        NaN   NaN      NaN  ...
#
#      noinsurance  physicians  pollution  diabetes  \
# 99           NaN         NaN        NaN       NaN
# 100          NaN         NaN        NaN       NaN
# 101          NaN         NaN        NaN       NaN
# 102          NaN         NaN        NaN       NaN
# 103          NaN         NaN        NaN       NaN
# 104          NaN         NaN        NaN       NaN
# 105          NaN         NaN        NaN       NaN
# 106          NaN         NaN        NaN       NaN
#
#                 county_and_state_y    code2  sunlight blow  ganj  smack
# 99                             NaN      NaN       NaN  NaN   NaN    NaN
# 100       District of Columbia, DC  11001.0  15265.36  NaN   NaN    NaN
# 101                Dade County, FL  12025.0  19744.21  NaN   NaN    NaN
# 102  Yellowstone National Park, MT  30113.0  16179.86  NaN   NaN    NaN
# 103             Shannon County, SD  46113.0  15680.32  NaN   NaN    NaN
# 104               Bedford city, VA  51515.0  16091.55  NaN   NaN    NaN
# 105         Clifton Forge city, VA  51560.0  15616.58  NaN   NaN    NaN
# 106         South Boston  city, VA  51780.0  16153.98  NaN   NaN    NaN
#
# [8 rows x 23 columns]

# %% [markdown]
# * These 8 are special cases that we can handle one by one now.
# * Next, let's look for NaN's in county names...

# %%
nocnty = cnty_df.loc[cnty_df.county.isnull(),:]
nocnty
# Out:
#       Unnamed: 0 county                 state county_and_state_x  code  \
# 67            67    NaN               Alabama                NaN   NaN
# 83            83    NaN                Alaska                NaN   NaN
# 100          100    NaN                   NaN                NaN   NaN
# 101          101    NaN                   NaN                NaN   NaN
# 102          102    NaN                   NaN                NaN   NaN
# 103          103    NaN                   NaN                NaN   NaN
# 104          104    NaN                   NaN                NaN   NaN
# 105          105    NaN                   NaN                NaN   NaN
# 106          106    NaN                   NaN                NaN   NaN
# 199          199    NaN               Indiana                NaN   NaN
# 267          267    NaN             Louisiana                NaN   NaN
# 282          282    NaN                Nevada                NaN   NaN
# 355          355    NaN          Pennsylvania                NaN   NaN
# 406          406    NaN          South Dakota                NaN   NaN
# 556          556    NaN              Virginia                NaN   NaN
# 611          611    NaN               Arizona                NaN   NaN
# 687          687    NaN              Arkansas                NaN   NaN
# 745          745    NaN            California                NaN   NaN
# 799          799    NaN              Colorado                NaN   NaN
# 820          820    NaN           Connecticut                NaN   NaN
# 824          824    NaN              Delaware                NaN   NaN
# 892          892    NaN               Florida                NaN   NaN
# 1049        1049    NaN               Georgia                NaN   NaN
# 1057        1057    NaN                Hawaii                NaN   NaN
# 1098        1098    NaN                 Idaho                NaN   NaN
# 1206        1206    NaN              Illinois                NaN   NaN
# 1306        1306    NaN                  Iowa                NaN   NaN
# 1396        1396    NaN                Kansas                NaN   NaN
# 1533        1533    NaN              Kentucky                NaN   NaN
# 1550        1550    NaN                 Maine                NaN   NaN
# ...          ...    ...                   ...                ...   ...
# 1762        1762    NaN             Minnesota                NaN   NaN
# 1845        1845    NaN           Mississippi                NaN   NaN
# 1961        1961    NaN              Missouri                NaN   NaN
# 2004        2004    NaN               Montana                NaN   NaN
# 2095        2095    NaN              Nebraska                NaN   NaN
# 2125        2125    NaN         New Hampshire                NaN   NaN
# 2147        2147    NaN            New Jersey                NaN   NaN
# 2176        2176    NaN            New Mexico                NaN   NaN
# 2244        2244    NaN              New York                NaN   NaN
# 2345        2345    NaN        North Carolina                NaN   NaN
# 2389        2389    NaN          North Dakota                NaN   NaN
# 2488        2488    NaN                  Ohio                NaN   NaN
# 2565        2565    NaN              Oklahoma                NaN   NaN
# 2601        2601    NaN                Oregon                NaN   NaN
# 2609        2609    NaN          Rhode Island                NaN   NaN
# 2656        2656    NaN        South Carolina                NaN   NaN
# 2752        2752    NaN             Tennessee                NaN   NaN
# 2973        2973    NaN                 Texas                NaN   NaN
# 3032        3032    NaN                  Utah                NaN   NaN
# 3052        3052    NaN               Vermont                NaN   NaN
# 3091        3091    NaN            Washington                NaN   NaN
# 3148        3148    NaN         West Virginia                NaN   NaN
# 3220        3220    NaN             Wisconsin                NaN   NaN
# 3244        3244    NaN               Wyoming                NaN   NaN
# 3246        3246    NaN  District of Columbia                NaN   NaN
# 3247        3247    NaN               Midwest                NaN   NaN
# 3248        3248    NaN             Northeast                NaN   NaN
# 3249        3249    NaN                 South                NaN   NaN
# 3250        3250    NaN   Total United States                NaN   NaN
# 3251        3251    NaN                  West                NaN   NaN
#
#       Deaths  Population Crude Rate     fips  smoking    ...     noinsurance  \
# 67       NaN         NaN        NaN   1000.0     22.0    ...            11.0
# 83       NaN         NaN        NaN   2000.0     19.0    ...            16.0
# 100      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 101      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 102      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 103      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 104      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 105      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 106      NaN         NaN        NaN      NaN      NaN    ...             NaN
# 199      NaN         NaN        NaN  18000.0     21.0    ...             9.0
# 267      NaN         NaN        NaN  22000.0     23.0    ...            12.0
# 282      NaN         NaN        NaN  32000.0     16.0    ...            13.0
# 355      NaN         NaN        NaN  42000.0     18.0    ...             7.0
# 406      NaN         NaN        NaN  46000.0     18.0    ...            10.0
# 556      NaN         NaN        NaN  51000.0     15.0    ...            10.0
# 611      NaN         NaN        NaN   4000.0     15.0    ...            12.0
# 687      NaN         NaN        NaN   5000.0     24.0    ...             9.0
# 745      NaN         NaN        NaN   6000.0     11.0    ...             8.0
# 799      NaN         NaN        NaN   8000.0     16.0    ...             9.0
# 820      NaN         NaN        NaN   9000.0     13.0    ...             6.0
# 824      NaN         NaN        NaN  10000.0     18.0    ...             7.0
# 892      NaN         NaN        NaN  12000.0     15.0    ...            15.0
# 1049     NaN         NaN        NaN  13000.0     18.0    ...            15.0
# 1057     NaN         NaN        NaN  15000.0     13.0    ...             4.0
# 1098     NaN         NaN        NaN  16000.0     14.0    ...            12.0
# 1206     NaN         NaN        NaN  17000.0     16.0    ...             7.0
# 1306     NaN         NaN        NaN  19000.0     17.0    ...             5.0
# 1396     NaN         NaN        NaN  20000.0     17.0    ...            10.0
# 1533     NaN         NaN        NaN  21000.0     24.0    ...             6.0
# 1550     NaN         NaN        NaN  23000.0     20.0    ...            10.0
# ...      ...         ...        ...      ...      ...    ...             ...
# 1762     NaN         NaN        NaN  27000.0     15.0    ...             5.0
# 1845     NaN         NaN        NaN  28000.0     23.0    ...            14.0
# 1961     NaN         NaN        NaN  29000.0     22.0    ...            11.0
# 2004     NaN         NaN        NaN  30000.0     19.0    ...            10.0
# 2095     NaN         NaN        NaN  31000.0     17.0    ...            10.0
# 2125     NaN         NaN        NaN  33000.0     18.0    ...             7.0
# 2147     NaN         NaN        NaN  34000.0     14.0    ...             9.0
# 2176     NaN         NaN        NaN  35000.0     17.0    ...            11.0
# 2244     NaN         NaN        NaN  36000.0     14.0    ...             7.0
# 2345     NaN         NaN        NaN  37000.0     18.0    ...            12.0
# 2389     NaN         NaN        NaN  38000.0     20.0    ...             8.0
# 2488     NaN         NaN        NaN  39000.0     23.0    ...             7.0
# 2565     NaN         NaN        NaN  40000.0     20.0    ...            16.0
# 2601     NaN         NaN        NaN  41000.0     16.0    ...             7.0
# 2609     NaN         NaN        NaN  44000.0     14.0    ...             5.0
# 2656     NaN         NaN        NaN  45000.0     20.0    ...            12.0
# 2752     NaN         NaN        NaN  47000.0     22.0    ...            11.0
# 2973     NaN         NaN        NaN  48000.0     14.0    ...            19.0
# 3032     NaN         NaN        NaN  49000.0      9.0    ...            10.0
# 3052     NaN         NaN        NaN  50000.0     17.0    ...             5.0
# 3091     NaN         NaN        NaN  53000.0     14.0    ...             7.0
# 3148     NaN         NaN        NaN  54000.0     25.0    ...             7.0
# 3220     NaN         NaN        NaN  55000.0     17.0    ...             6.0
# 3244     NaN         NaN        NaN  56000.0     19.0    ...            13.0
# 3246     NaN         NaN        NaN      NaN      NaN    ...             NaN
# 3247     NaN         NaN        NaN      NaN      NaN    ...             NaN
# 3248     NaN         NaN        NaN      NaN      NaN    ...             NaN
# 3249     NaN         NaN        NaN      NaN      NaN    ...             NaN
# 3250     NaN         NaN        NaN      NaN      NaN    ...             NaN
# 3251     NaN         NaN        NaN      NaN      NaN    ...             NaN
#
#       physicians  pollution  diabetes             county_and_state_y    code2  \
# 67          65.0       11.0      14.0                            NaN      NaN
# 83          90.0        NaN       8.0                            NaN      NaN
# 100          NaN        NaN       NaN       District of Columbia, DC  11001.0
# 101          NaN        NaN       NaN                Dade County, FL  12025.0
# 102          NaN        NaN       NaN  Yellowstone National Park, MT  30113.0
# 103          NaN        NaN       NaN             Shannon County, SD  46113.0
# 104          NaN        NaN       NaN               Bedford city, VA  51515.0
# 105          NaN        NaN       NaN         Clifton Forge city, VA  51560.0
# 106          NaN        NaN       NaN         South Boston  city, VA  51780.0
# 199         67.0       11.8       NaN                            NaN      NaN
# 267         67.0        9.4       NaN                            NaN      NaN
# 282         57.0        6.5      10.0                            NaN      NaN
# 355         81.0       10.6      11.0                            NaN      NaN
# 406         76.0        5.6       9.0                            NaN      NaN
# 556         76.0        8.9      10.0                            NaN      NaN
# 611         65.0        5.8      10.0                            NaN      NaN
# 687         66.0       10.0      13.0                            NaN      NaN
# 745         78.0        9.5       9.0                            NaN      NaN
# 799         81.0        5.1       6.0                            NaN      NaN
# 820         85.0        8.0       9.0                            NaN      NaN
# 824         71.0        9.3      12.0                            NaN      NaN
# 892         72.0        8.2      11.0                            NaN      NaN
# 1049        66.0       10.9      12.0                            NaN      NaN
# 1057        88.0        NaN      10.0                            NaN      NaN
# 1098        65.0        7.4       9.0                            NaN      NaN
# 1206        81.0       11.5       NaN                            NaN      NaN
# 1306        72.0        9.0       NaN                            NaN      NaN
# 1396        76.0        8.1       NaN                            NaN      NaN
# 1533        66.0       10.7       NaN                            NaN      NaN
# 1550       112.0        7.4       NaN                            NaN      NaN
# ...          ...        ...       ...                            ...      ...
# 1762        89.0        6.9       NaN                            NaN      NaN
# 1845        53.0        9.9       NaN                            NaN      NaN
# 1961        71.0        9.7      12.0                            NaN      NaN
# 2004        74.0        6.0       8.0                            NaN      NaN
# 2095        76.0        7.5       9.0                            NaN      NaN
# 2125        91.0        7.5       9.0                            NaN      NaN
# 2147        84.0        9.9       9.0                            NaN      NaN
# 2176        74.0        5.9       9.0                            NaN      NaN
# 2244        83.0        8.5      10.0                            NaN      NaN
# 2345        70.0        9.8      11.0                            NaN      NaN
# 2389        76.0        5.4       9.0                            NaN      NaN
# 2488        77.0       11.5      12.0                            NaN      NaN
# 2565        63.0        9.4      12.0                            NaN      NaN
# 2601        92.0        7.9       9.0                            NaN      NaN
# 2609        96.0        6.6      10.0                            NaN      NaN
# 2656        67.0       10.2      13.0                            NaN      NaN
# 2752        72.0       10.0      13.0                            NaN      NaN
# 2973        60.0        8.8      10.0                            NaN      NaN
# 3032        57.0        5.6       7.0                            NaN      NaN
# 3052       113.0        6.5       8.0                            NaN      NaN
# 3091        82.0        7.4       9.0                            NaN      NaN
# 3148        79.0        9.6      14.0                            NaN      NaN
# 3220        80.0        8.6       9.0                            NaN      NaN
# 3244        68.0        4.8       9.0                            NaN      NaN
# 3246         NaN        NaN       NaN                            NaN      NaN
# 3247         NaN        NaN       NaN                            NaN      NaN
# 3248         NaN        NaN       NaN                            NaN      NaN
# 3249         NaN        NaN       NaN                            NaN      NaN
# 3250         NaN        NaN       NaN                            NaN      NaN
# 3251         NaN        NaN       NaN                            NaN      NaN
#
#       sunlight      blow       ganj     smack
# 67         NaN  1.158000   9.282000  0.276000
# 83         NaN  2.056000  23.180000  0.806000
# 100   15265.36       NaN        NaN       NaN
# 101   19744.21       NaN        NaN       NaN
# 102   16179.86       NaN        NaN       NaN
# 103   15680.32       NaN        NaN       NaN
# 104   16091.55       NaN        NaN       NaN
# 105   15616.58       NaN        NaN       NaN
# 106   16153.98       NaN        NaN       NaN
# 199        NaN  1.167778  13.688889  0.440000
# 267        NaN  1.797500  11.853750  0.170000
# 282        NaN  1.758333  12.883333  0.356667
# 355        NaN  1.624286  12.271429  0.619286
# 406        NaN  0.978333  11.028333  0.248333
# 556        NaN  1.455000  11.498333  0.401667
# 611        NaN  2.238333  12.050000  0.513333
# 687        NaN  1.108889  11.220000  0.191111
# 745        NaN  2.502500  16.200000  0.216071
# 799        NaN  2.492500  22.612500  0.351250
# 820        NaN  2.371667  15.066667  0.673333
# 824        NaN  1.960000  14.700000  1.022000
# 892        NaN  1.869583  13.364583  0.269583
# 1049       NaN  1.604286  11.800000  0.137143
# 1057       NaN  2.170000  14.800000  0.226000
# 1098       NaN  1.127500  11.548750  0.290000
# 1206       NaN  1.866522  12.853478  0.305652
# 1306       NaN  1.030000   9.175714  0.147143
# 1396       NaN  1.213333  10.960000  0.188333
# 1533       NaN  1.517143  12.185714  0.500000
# 1550       NaN  1.711000  19.970000  0.473000
# ...        ...       ...        ...       ...
# 1762       NaN  1.440000  12.264286  0.267143
# 1845       NaN  1.060000   9.192500  0.185000
# 1961       NaN  1.224000  13.400000  0.311000
# 2004       NaN  1.580000  15.966667  0.288333
# 2095       NaN  1.293750  10.088750  0.232500
# 2125       NaN  2.786250  17.850000  0.635000
# 2147       NaN  1.826000  12.180000  0.634000
# 2176       NaN  1.977500  15.412500  0.237500
# 2244       NaN  2.573529  14.947059  0.488824
# 2345       NaN  1.756667  11.939333  0.335333
# 2389       NaN  1.116000   9.221000  0.225000
# 2488       NaN  1.533182  12.104091  0.372727
# 2565       NaN  1.042500  10.797500  0.238750
# 2601       NaN  2.460000  20.871429  0.427143
# 2609       NaN  2.578750  19.950000  0.490000
# 2656       NaN  1.474000  11.318000  0.252000
# 2752       NaN  1.488750  11.655000  0.268750
# 2973       NaN  1.472500  10.073500  0.203000
# 3032       NaN  0.891111   8.982222  0.325556
# 3052       NaN  2.884000  20.660000  0.744000
# 3091       NaN  1.783333  18.583333  0.462500
# 3148       NaN  1.287143  10.990000  0.498571
# 3220       NaN  1.477143  12.271429  0.332857
# 3244       NaN  1.331000  10.965000  0.234000
# 3246       NaN  3.425556  24.177778  0.472222
# 3247       NaN  1.430000  12.800000  0.310000
# 3248       NaN  2.250000  14.800000  0.530000
# 3249       NaN  1.530000  11.600000  0.280000
# 3250       NaN  1.800000  13.500000  0.340000
# 3251       NaN  2.230000  16.100000  0.300000
#
# [63 rows x 23 columns]

# %% [markdown]
# * For these 63 cases, we have 51 excess "state" names where there are just stats for the whole state.  In those cases we have everything but sunlight.
# * Of the remaining 12 cases, there are 5 -- regions + total US, where we just have aggregated drug use data.
# * That leaves 7 extra cases, which are all part of the "special cases" we found earlier

# %%
# 1.  Miami-Dade County is the same as Dade County, we need to merge those rows, but we can't do it on codes because
# Miami-Dade has fips 12086 while the old Dade County has fips 12025.  But we can find them
cnty_df.loc[cnty_df.county_and_state_y == 'Dade County, FL',:]
# Out:
#      Unnamed: 0 county state county_and_state_x  code  Deaths  Population  \
# 101         101    NaN   NaN                NaN   NaN     NaN         NaN
#
#     Crude Rate  fips  smoking  ...    noinsurance  physicians  pollution  \
# 101        NaN   NaN      NaN  ...            NaN         NaN        NaN
#
#      diabetes  county_and_state_y    code2  sunlight blow  ganj  smack
# 101       NaN     Dade County, FL  12025.0  19744.21  NaN   NaN    NaN
#
# [1 rows x 23 columns]

# %%
# The other row
cnty_df.loc[cnty_df.county == 'Miami-Dade',:]
# Out:
#      Unnamed: 0      county    state     county_and_state_x     code  Deaths  \
# 867         867  Miami-Dade  Florida  Miami-Dade County, FL  12086.0  7255.0
#
#      Population Crude Rate     fips  smoking    ...     noinsurance  \
# 867   2712945.0      267.4  12086.0     14.0    ...            19.0
#
#      physicians  pollution  diabetes  county_and_state_y  code2  sunlight  \
# 867        80.0        7.2       8.0                 NaN    NaN       NaN
#
#          blow       ganj     smack
# 867  1.869583  13.364583  0.269583
#
# [1 rows x 23 columns]

# %%
# If we just move three values (columns 17 to 19) to row 867 from row 101, we are good.
for n in range(17,20):
    cnty_df.iat[867,n] = cnty_df.iat[101,n]
# Then delete row 101
cnty_df = cnty_df.drop(index=101,axis=0)
cnty_df.iloc[99:110]
# Out:
#      Unnamed: 0                    county    state        county_and_state_x  \
# 99           99  District of Columbia, DC      NaN  District of Columbia, DC
# 100         100                       NaN      NaN                       NaN
# 102         102                       NaN      NaN                       NaN
# 103         103                       NaN      NaN                       NaN
# 104         104                       NaN      NaN                       NaN
# 105         105                       NaN      NaN                       NaN
# 106         106                       NaN      NaN                       NaN
# 107         107                   De Kalb  Indiana        De Kalb County, IN
# 108         108                  Lagrange  Indiana       Lagrange County, IN
# 109         109                  La Porte  Indiana       La Porte County, IN
# 110         110                     Adams  Indiana          Adams County, IN
#
#         code  Deaths  Population Crude Rate     fips  smoking  ...    \
# 99   11001.0  1752.0    681170.0      257.2      NaN      NaN  ...
# 100      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 102      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 103      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 104      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 105      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 106      NaN     NaN         NaN        NaN      NaN      NaN  ...
# 107  18033.0   114.0     42746.0      266.7      NaN      NaN  ...
# 108  18087.0    87.0     39110.0      222.4      NaN      NaN  ...
# 109  18091.0   404.0    110015.0      367.2      NaN      NaN  ...
# 110  18001.0   104.0     35232.0      295.2  18001.0     21.0  ...
#
#      noinsurance  physicians  pollution  diabetes  \
# 99           NaN         NaN        NaN       NaN
# 100          NaN         NaN        NaN       NaN
# 102          NaN         NaN        NaN       NaN
# 103          NaN         NaN        NaN       NaN
# 104          NaN         NaN        NaN       NaN
# 105          NaN         NaN        NaN       NaN
# 106          NaN         NaN        NaN       NaN
# 107          NaN         NaN        NaN       NaN
# 108          NaN         NaN        NaN       NaN
# 109          NaN         NaN        NaN       NaN
# 110         12.0        34.0       12.5       NaN
#
#                 county_and_state_y    code2  sunlight      blow       ganj  \
# 99                             NaN      NaN       NaN       NaN        NaN
# 100       District of Columbia, DC  11001.0  15265.36       NaN        NaN
# 102  Yellowstone National Park, MT  30113.0  16179.86       NaN        NaN
# 103             Shannon County, SD  46113.0  15680.32       NaN        NaN
# 104               Bedford city, VA  51515.0  16091.55       NaN        NaN
# 105         Clifton Forge city, VA  51560.0  15616.58       NaN        NaN
# 106         South Boston  city, VA  51780.0  16153.98       NaN        NaN
# 107                            NaN      NaN       NaN  1.167778  13.688889
# 108                            NaN      NaN       NaN  1.167778  13.688889
# 109                            NaN      NaN       NaN  1.167778  13.688889
# 110               Adams County, IN  18001.0  14630.84  1.167778  13.688889
#
#      smack
# 99     NaN
# 100    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107   0.44
# 108   0.44
# 109   0.44
# 110   0.44
#
# [11 rows x 23 columns]

# %%
cnty_df.iat[3245,2]
# Out:
# 'District of Columbia'

# %%
#Next is the District of Columbia.  Same thing, just rows 100 and 99
for n in range(17,20):
    cnty_df.iat[99,n] = cnty_df.iat[100,n]
# Then copy the drug data from row 3245
for n in range(20,23):
    cnty_df.iat[99,n] = cnty_df.iat[3245,n]
# Then delete row 101
cnty_df = cnty_df.drop(index=100,axis=0)
cnty_df.iloc[99:105,:]
# Out:
#      Unnamed: 0                    county state        county_and_state_x  \
# 99           99  District of Columbia, DC   NaN  District of Columbia, DC
# 102         102                       NaN   NaN                       NaN
# 103         103                       NaN   NaN                       NaN
# 104         104                       NaN   NaN                       NaN
# 105         105                       NaN   NaN                       NaN
# 106         106                       NaN   NaN                       NaN
#
#         code  Deaths  Population Crude Rate  fips  smoking    ...     \
# 99   11001.0  1752.0    681170.0      257.2   NaN      NaN    ...
# 102      NaN     NaN         NaN        NaN   NaN      NaN    ...
# 103      NaN     NaN         NaN        NaN   NaN      NaN    ...
# 104      NaN     NaN         NaN        NaN   NaN      NaN    ...
# 105      NaN     NaN         NaN        NaN   NaN      NaN    ...
# 106      NaN     NaN         NaN        NaN   NaN      NaN    ...
#
#      noinsurance  physicians  pollution  diabetes  \
# 99           NaN         NaN        NaN       NaN
# 102          NaN         NaN        NaN       NaN
# 103          NaN         NaN        NaN       NaN
# 104          NaN         NaN        NaN       NaN
# 105          NaN         NaN        NaN       NaN
# 106          NaN         NaN        NaN       NaN
#
#                 county_and_state_y    code2  sunlight      blow       ganj  \
# 99        District of Columbia, DC  11001.0  15265.36  3.425556  24.177778
# 102  Yellowstone National Park, MT  30113.0  16179.86       NaN        NaN
# 103             Shannon County, SD  46113.0  15680.32       NaN        NaN
# 104               Bedford city, VA  51515.0  16091.55       NaN        NaN
# 105         Clifton Forge city, VA  51560.0  15616.58       NaN        NaN
# 106         South Boston  city, VA  51780.0  16153.98       NaN        NaN
#
#         smack
# 99   0.472222
# 102       NaN
# 103       NaN
# 104       NaN
# 105       NaN
# 106       NaN
#
# [6 rows x 23 columns]

# %%
# Next is Yellowstone National Park.  Turns out that county was merged into another county, so we can just delete it...
cnty_df = cnty_df.drop(index=102,axis=0)
# Same thing for South Boston
cnty_df = cnty_df.drop(index=105,axis=0)
# ... and Clifton Forge
cnty_df = cnty_df.drop(index=106,axis=0)
cnty_df.iloc[99:110,:]
# Out:
#      Unnamed: 0                    county    state        county_and_state_x  \
# 99           99  District of Columbia, DC      NaN  District of Columbia, DC
# 103         103                       NaN      NaN                       NaN
# 104         104                       NaN      NaN                       NaN
# 107         107                   De Kalb  Indiana        De Kalb County, IN
# 108         108                  Lagrange  Indiana       Lagrange County, IN
# 109         109                  La Porte  Indiana       La Porte County, IN
# 110         110                     Adams  Indiana          Adams County, IN
# 111         111                     Allen  Indiana          Allen County, IN
# 112         112               Bartholomew  Indiana    Bartholomew County, IN
# 113         113                    Benton  Indiana         Benton County, IN
# 114         114                 Blackford  Indiana      Blackford County, IN
#
#         code  Deaths  Population Crude Rate     fips  smoking    ...     \
# 99   11001.0  1752.0    681170.0      257.2      NaN      NaN    ...
# 103      NaN     NaN         NaN        NaN      NaN      NaN    ...
# 104      NaN     NaN         NaN        NaN      NaN      NaN    ...
# 107  18033.0   114.0     42746.0      266.7      NaN      NaN    ...
# 108  18087.0    87.0     39110.0      222.4      NaN      NaN    ...
# 109  18091.0   404.0    110015.0      367.2      NaN      NaN    ...
# 110  18001.0   104.0     35232.0      295.2  18001.0     21.0    ...
# 111  18003.0   937.0    370404.0        253  18003.0     19.0    ...
# 112  18005.0   226.0     81402.0      277.6  18005.0     18.0    ...
# 113  18007.0    23.0      8650.0      265.9  18007.0     21.0    ...
# 114  18009.0    44.0     12149.0      362.2  18009.0     20.0    ...
#
#      noinsurance  physicians  pollution  diabetes        county_and_state_y  \
# 99           NaN         NaN        NaN       NaN  District of Columbia, DC
# 103          NaN         NaN        NaN       NaN        Shannon County, SD
# 104          NaN         NaN        NaN       NaN          Bedford city, VA
# 107          NaN         NaN        NaN       NaN                       NaN
# 108          NaN         NaN        NaN       NaN                       NaN
# 109          NaN         NaN        NaN       NaN                       NaN
# 110         12.0        34.0       12.5       NaN          Adams County, IN
# 111          9.0        65.0       12.6       NaN          Allen County, IN
# 112         10.0        75.0       11.2       NaN    Bartholomew County, IN
# 113         12.0         NaN       11.0       NaN         Benton County, IN
# 114         10.0        58.0       11.7       NaN      Blackford County, IN
#
#        code2  sunlight      blow       ganj     smack
# 99   11001.0  15265.36  3.425556  24.177778  0.472222
# 103  46113.0  15680.32       NaN        NaN       NaN
# 104  51515.0  16091.55       NaN        NaN       NaN
# 107      NaN       NaN  1.167778  13.688889  0.440000
# 108      NaN       NaN  1.167778  13.688889  0.440000
# 109      NaN       NaN  1.167778  13.688889  0.440000
# 110  18001.0  14630.84  1.167778  13.688889  0.440000
# 111  18003.0  14540.99  1.167778  13.688889  0.440000
# 112  18005.0  15055.18  1.167778  13.688889  0.440000
# 113  18007.0  14809.22  1.167778  13.688889  0.440000
# 114  18009.0  14721.17  1.167778  13.688889  0.440000
#
# [11 rows x 23 columns]

# %%
# Now just deal with Bedford, VA and Shannon, SD.
# For Shannon, SD, we'll just merge as we did before, but first we will reset the index to make it easier...
cnty_df = cnty_df.reset_index()
cnty_df.head()
# Out:
#    index  Unnamed: 0   county    state  county_and_state_x    code  Deaths  \
# 0      0           0  Autauga  Alabama  Autauga County, AL  1001.0   163.0
# 1      1           1  Baldwin  Alabama  Baldwin County, AL  1003.0   640.0
# 2      2           2  Barbour  Alabama  Barbour County, AL  1005.0    90.0
# 3      3           3     Bibb  Alabama     Bibb County, AL  1007.0    79.0
# 4      4           4   Blount  Alabama   Blount County, AL  1009.0   199.0
#
#    Population Crude Rate    fips  ...    noinsurance  physicians  pollution  \
# 0     55416.0      294.1  1001.0  ...            9.0        42.0       11.7
# 1    208563.0      306.9  1003.0  ...           11.0        73.0       10.3
# 2     25965.0      346.6  1005.0  ...           13.0        39.0       11.5
# 3     22643.0      348.9  1007.0  ...           10.0        57.0       11.2
# 4     57704.0      344.9  1009.0  ...           12.0        23.0       11.7
#
#    diabetes  county_and_state_y   code2  sunlight   blow   ganj  smack
# 0      14.0  Autauga County, AL  1001.0  17103.72  1.158  9.282  0.276
# 1      11.0  Baldwin County, AL  1003.0  17660.59  1.158  9.282  0.276
# 2      18.0  Barbour County, AL  1005.0  17315.13  1.158  9.282  0.276
# 3      15.0     Bibb County, AL  1007.0  16904.87  1.158  9.282  0.276
# 4      14.0   Blount County, AL  1009.0  16393.63  1.158  9.282  0.276
#
# [5 rows x 24 columns]

# %%
# Check where the new rows are
cnty_df.loc[cnty_df.county_and_state_x == 'Shannon County, SD',:]
# Out:
#      index  Unnamed: 0   county         state  county_and_state_x     code  \
# 352    357         357  Shannon  South Dakota  Shannon County, SD  46113.0
#
#      Deaths  Population          Crude Rate  fips    ...     noinsurance  \
# 352    17.0     14415.0  117.9 (Unreliable)   NaN    ...             NaN
#
#      physicians  pollution  diabetes  county_and_state_y  code2  sunlight  \
# 352         NaN        NaN       NaN                 NaN    NaN       NaN
#
#          blow       ganj     smack
# 352  0.978333  11.028333  0.248333
#
# [1 rows x 24 columns]

# %%
cnty_df.loc[cnty_df.county_and_state_y == 'Shannon County, SD',:]
# Out:
#      index  Unnamed: 0 county state county_and_state_x  code  Deaths  \
# 100    103         103    NaN   NaN                NaN   NaN     NaN
#
#      Population Crude Rate  fips  ...    noinsurance  physicians  pollution  \
# 100         NaN        NaN   NaN  ...            NaN         NaN        NaN
#
#      diabetes  county_and_state_y    code2  sunlight  blow ganj  smack
# 100       NaN  Shannon County, SD  46113.0  15680.32   NaN  NaN    NaN
#
# [1 rows x 24 columns]

# %%
for n in range(17,20):
    cnty_df.iat[352,n] = cnty_df.iat[100,n]
# Then delete row 101
cnty_df = cnty_df.drop(index=100,axis=0)
cnty_df.iloc[99:105,:]
# Out:
#      index  Unnamed: 0                    county    state  \
# 99      99          99  District of Columbia, DC      NaN
# 101    104         104                       NaN      NaN
# 102    107         107                   De Kalb  Indiana
# 103    108         108                  Lagrange  Indiana
# 104    109         109                  La Porte  Indiana
# 105    110         110                     Adams  Indiana
#
#            county_and_state_x     code  Deaths  Population Crude Rate  \
# 99   District of Columbia, DC  11001.0  1752.0    681170.0      257.2
# 101                       NaN      NaN     NaN         NaN        NaN
# 102        De Kalb County, IN  18033.0   114.0     42746.0      266.7
# 103       Lagrange County, IN  18087.0    87.0     39110.0      222.4
# 104       La Porte County, IN  18091.0   404.0    110015.0      367.2
# 105          Adams County, IN  18001.0   104.0     35232.0      295.2
#
#         fips    ...     noinsurance  physicians  pollution  diabetes  \
# 99       NaN    ...             NaN         NaN        NaN       NaN
# 101      NaN    ...             NaN         NaN        NaN       NaN
# 102      NaN    ...             NaN         NaN        NaN       NaN
# 103      NaN    ...             NaN         NaN        NaN       NaN
# 104      NaN    ...             NaN         NaN        NaN       NaN
# 105  18001.0    ...            12.0        34.0       12.5       NaN
#
#            county_and_state_y    code2  sunlight      blow       ganj  \
# 99   District of Columbia, DC  11001.0  15265.36  3.425556  24.177778
# 101          Bedford city, VA  51515.0  16091.55       NaN        NaN
# 102                       NaN      NaN       NaN  1.167778  13.688889
# 103                       NaN      NaN       NaN  1.167778  13.688889
# 104                       NaN      NaN       NaN  1.167778  13.688889
# 105          Adams County, IN  18001.0  14630.84  1.167778  13.688889
#
#         smack
# 99   0.472222
# 101       NaN
# 102  0.440000
# 103  0.440000
# 104  0.440000
# 105  0.440000
#
# [6 rows x 24 columns]

# %%
# Last but not least is Bedford city, VA ... note there could be a Bedford county in VA also ...
# Let's find all Bedford counties ...
cnty_df.loc[cnty_df.county == 'Bedford',:]
# Out:
#       index  Unnamed: 0   county         state  county_and_state_x     code  \
# 288     293         293  Bedford  Pennsylvania  Bedford County, PA  42009.0
# 462     467         467  Bedford      Virginia  Bedford County, VA  51019.0
# 2653   2658        2658  Bedford     Tennessee  Bedford County, TN  47003.0
#
#       Deaths  Population Crude Rate     fips    ...     noinsurance  \
# 288    200.0     48325.0      413.9  42009.0    ...             8.0
# 462    233.0     77960.0      298.9  51019.0    ...             9.0
# 2653   172.0     47484.0      362.2  47003.0    ...            13.0
#
#       physicians  pollution  diabetes  county_and_state_y    code2  sunlight  \
# 288         25.0       10.6      13.0  Bedford County, PA  42009.0  14434.89
# 462         71.0        9.2      14.0  Bedford County, VA  51019.0  16053.66
# 2653        38.0       10.5      12.0  Bedford County, TN  47003.0  15851.13
#
#           blow       ganj     smack
# 288   1.624286  12.271429  0.619286
# 462   1.455000  11.498333  0.401667
# 2653  1.488750  11.655000  0.268750
#
# [3 rows x 24 columns]

# %%
# OK, only one Bedford County, VA.  After some research ... turns out Bedford city joined Bedford county in 2013
# so we can just delete it.
cnty_df = cnty_df.drop(index=101,axis=0)
cnty_df = cnty_df.reset_index()

# %%
# Now let's clear out some unused columns ...
cnty_df = cnty_df.drop(columns = ['level_0','index','Unnamed: 0'])
cnty_df.head()
# Out:
#     county    state  county_and_state_x    code  Deaths  Population  \
# 0  Autauga  Alabama  Autauga County, AL  1001.0   163.0     55416.0
# 1  Baldwin  Alabama  Baldwin County, AL  1003.0   640.0    208563.0
# 2  Barbour  Alabama  Barbour County, AL  1005.0    90.0     25965.0
# 3     Bibb  Alabama     Bibb County, AL  1007.0    79.0     22643.0
# 4   Blount  Alabama   Blount County, AL  1009.0   199.0     57704.0
#
#   Crude Rate    fips  smoking  obesity  ...    noinsurance  physicians  \
# 0      294.1  1001.0     19.0     38.0  ...            9.0        42.0
# 1      306.9  1003.0     17.0     31.0  ...           11.0        73.0
# 2      346.6  1005.0     22.0     44.0  ...           13.0        39.0
# 3      348.9  1007.0     20.0     38.0  ...           10.0        57.0
# 4      344.9  1009.0     20.0     34.0  ...           12.0        23.0
#
#    pollution  diabetes  county_and_state_y   code2  sunlight   blow   ganj  \
# 0       11.7      14.0  Autauga County, AL  1001.0  17103.72  1.158  9.282
# 1       10.3      11.0  Baldwin County, AL  1003.0  17660.59  1.158  9.282
# 2       11.5      18.0  Barbour County, AL  1005.0  17315.13  1.158  9.282
# 3       11.2      15.0     Bibb County, AL  1007.0  16904.87  1.158  9.282
# 4       11.7      14.0   Blount County, AL  1009.0  16393.63  1.158  9.282
#
#    smack
# 0  0.276
# 1  0.276
# 2  0.276
# 3  0.276
# 4  0.276
#
# [5 rows x 22 columns]

# %%
# Last fix, put "DC" as the state for DC, and copy the drug data there too
cnty_df.iat[99,1] = 'District of Columbia'
cnty_df.iloc[99:102,:]
# Out:
#                        county                 state        county_and_state_x  \
# 99   District of Columbia, DC  District of Columbia  District of Columbia, DC
# 100                   De Kalb               Indiana        De Kalb County, IN
# 101                  Lagrange               Indiana       Lagrange County, IN
#
#         code  Deaths  Population Crude Rate  fips  smoking  obesity    ...     \
# 99   11001.0  1752.0    681170.0      257.2   NaN      NaN      NaN    ...
# 100  18033.0   114.0     42746.0      266.7   NaN      NaN      NaN    ...
# 101  18087.0    87.0     39110.0      222.4   NaN      NaN      NaN    ...
#
#      noinsurance  physicians  pollution  diabetes        county_and_state_y  \
# 99           NaN         NaN        NaN       NaN  District of Columbia, DC
# 100          NaN         NaN        NaN       NaN                       NaN
# 101          NaN         NaN        NaN       NaN                       NaN
#
#        code2  sunlight      blow       ganj     smack
# 99   11001.0  15265.36  3.425556  24.177778  0.472222
# 100      NaN       NaN  1.167778  13.688889  0.440000
# 101      NaN       NaN  1.167778  13.688889  0.440000
#
# [3 rows x 22 columns]

# %%
# Last, let's get rid of the duplicate row 3239 for DC...
cnty_df = cnty_df.drop(index = 3239, axis = 0)
cnty_df.tail(10)
# Out:
#         county                state   county_and_state_x     code  Deaths  \
# 3234     Uinta              Wyoming     Uinta County, WY  56041.0    42.0
# 3235  Washakie              Wyoming  Washakie County, WY  56043.0    18.0
# 3236    Weston              Wyoming    Weston County, WY  56045.0    21.0
# 3237       NaN              Wyoming                  NaN      NaN     NaN
# 3238  Niobrara              Wyoming                  NaN      NaN     NaN
# 3240       NaN              Midwest                  NaN      NaN     NaN
# 3241       NaN            Northeast                  NaN      NaN     NaN
# 3242       NaN                South                  NaN      NaN     NaN
# 3243       NaN  Total United States                  NaN      NaN     NaN
# 3244       NaN                 West                  NaN      NaN     NaN
#
#       Population          Crude Rate     fips  smoking  obesity  ...    \
# 3234     20773.0               202.2  56041.0     18.0     32.0  ...
# 3235      8235.0  218.6 (Unreliable)  56043.0     16.0     30.0  ...
# 3236      7236.0               290.2  56045.0     17.0     31.0  ...
# 3237         NaN                 NaN  56000.0     19.0     29.0  ...
# 3238         NaN                 NaN  56027.0     17.0     25.0  ...
# 3240         NaN                 NaN      NaN      NaN      NaN  ...
# 3241         NaN                 NaN      NaN      NaN      NaN  ...
# 3242         NaN                 NaN      NaN      NaN      NaN  ...
# 3243         NaN                 NaN      NaN      NaN      NaN  ...
# 3244         NaN                 NaN      NaN      NaN      NaN  ...
#
#       noinsurance  physicians  pollution  diabetes   county_and_state_y  \
# 3234         13.0        39.0        5.9       9.0     Uinta County, WY
# 3235         17.0        49.0        4.8      11.0  Washakie County, WY
# 3236         14.0        41.0        4.1       9.0    Weston County, WY
# 3237         13.0        68.0        4.8       9.0                  NaN
# 3238         16.0        40.0        3.3       8.0  Niobrara County, WY
# 3240          NaN         NaN        NaN       NaN                  NaN
# 3241          NaN         NaN        NaN       NaN                  NaN
# 3242          NaN         NaN        NaN       NaN                  NaN
# 3243          NaN         NaN        NaN       NaN                  NaN
# 3244          NaN         NaN        NaN       NaN                  NaN
#
#         code2  sunlight   blow    ganj  smack
# 3234  56041.0  17123.76  1.331  10.965  0.234
# 3235  56043.0  16171.03  1.331  10.965  0.234
# 3236  56045.0  15923.65  1.331  10.965  0.234
# 3237      NaN       NaN  1.331  10.965  0.234
# 3238  56027.0  16054.19  1.331  10.965  0.234
# 3240      NaN       NaN  1.430  12.800  0.310
# 3241      NaN       NaN  2.250  14.800  0.530
# 3242      NaN       NaN  1.530  11.600  0.280
# 3243      NaN       NaN  1.800  13.500  0.340
# 3244      NaN       NaN  2.230  16.100  0.300
#
# [10 rows x 22 columns]

# %% [markdown]
# * Now, we will save this combined file, and then generate separate county and state only files...

# %%
cnty_df.to_csv('Extra_Output/merged_county_state_region.csv')

# %%
# We want to check that there are just 55 excess entries in this table that do not have a county.
len(cnty_df) - cnty_df.county.count()
# Out:
# 55

# %%
# To generate counties only, make a new DataFrame that drops the na values from county
cnty_only = cnty_df.dropna(subset=['county'])
cnty_only.tail()
# Out:
#         county    state   county_and_state_x     code  Deaths  Population  \
# 3233     Teton  Wyoming     Teton County, WY  56039.0    21.0     23191.0
# 3234     Uinta  Wyoming     Uinta County, WY  56041.0    42.0     20773.0
# 3235  Washakie  Wyoming  Washakie County, WY  56043.0    18.0      8235.0
# 3236    Weston  Wyoming    Weston County, WY  56045.0    21.0      7236.0
# 3238  Niobrara  Wyoming                  NaN      NaN     NaN         NaN
#
#               Crude Rate     fips  smoking  obesity  ...    noinsurance  \
# 3233                90.6  56039.0     14.0     14.0  ...           15.0
# 3234               202.2  56041.0     18.0     32.0  ...           13.0
# 3235  218.6 (Unreliable)  56043.0     16.0     30.0  ...           17.0
# 3236               290.2  56045.0     17.0     31.0  ...           14.0
# 3238                 NaN  56027.0     17.0     25.0  ...           16.0
#
#       physicians  pollution  diabetes   county_and_state_y    code2  sunlight  \
# 3233       121.0        4.9       4.0     Teton County, WY  56039.0  16531.32
# 3234        39.0        5.9       9.0     Uinta County, WY  56041.0  17123.76
# 3235        49.0        4.8      11.0  Washakie County, WY  56043.0  16171.03
# 3236        41.0        4.1       9.0    Weston County, WY  56045.0  15923.65
# 3238        40.0        3.3       8.0  Niobrara County, WY  56027.0  16054.19
#
#        blow    ganj  smack
# 3233  1.331  10.965  0.234
# 3234  1.331  10.965  0.234
# 3235  1.331  10.965  0.234
# 3236  1.331  10.965  0.234
# 3238  1.331  10.965  0.234
#
# [5 rows x 22 columns]

# %%
# Save this file
cnty_only.to_csv('merged_counties_only.csv')

# %%
# To make only the state file, we will re-make the 'no county' table and then just trim the regions...
nocnty2 = cnty_df.loc[cnty_df.county.isnull(),:]
nocnty2.tail(10)
# Out:
#      county                state county_and_state_x  code  Deaths  Population  \
# 3045    NaN              Vermont                NaN   NaN     NaN         NaN
# 3084    NaN           Washington                NaN   NaN     NaN         NaN
# 3141    NaN        West Virginia                NaN   NaN     NaN         NaN
# 3213    NaN            Wisconsin                NaN   NaN     NaN         NaN
# 3237    NaN              Wyoming                NaN   NaN     NaN         NaN
# 3240    NaN              Midwest                NaN   NaN     NaN         NaN
# 3241    NaN            Northeast                NaN   NaN     NaN         NaN
# 3242    NaN                South                NaN   NaN     NaN         NaN
# 3243    NaN  Total United States                NaN   NaN     NaN         NaN
# 3244    NaN                 West                NaN   NaN     NaN         NaN
#
#      Crude Rate     fips  smoking  obesity    ...     noinsurance  physicians  \
# 3045        NaN  50000.0     17.0     26.0    ...             5.0       113.0
# 3084        NaN  53000.0     14.0     28.0    ...             7.0        82.0
# 3141        NaN  54000.0     25.0     36.0    ...             7.0        79.0
# 3213        NaN  55000.0     17.0     31.0    ...             6.0        80.0
# 3237        NaN  56000.0     19.0     29.0    ...            13.0        68.0
# 3240        NaN      NaN      NaN      NaN    ...             NaN         NaN
# 3241        NaN      NaN      NaN      NaN    ...             NaN         NaN
# 3242        NaN      NaN      NaN      NaN    ...             NaN         NaN
# 3243        NaN      NaN      NaN      NaN    ...             NaN         NaN
# 3244        NaN      NaN      NaN      NaN    ...             NaN         NaN
#
#       pollution  diabetes  county_and_state_y  code2 sunlight      blow  \
# 3045        6.5       8.0                 NaN    NaN      NaN  2.884000
# 3084        7.4       9.0                 NaN    NaN      NaN  1.783333
# 3141        9.6      14.0                 NaN    NaN      NaN  1.287143
# 3213        8.6       9.0                 NaN    NaN      NaN  1.477143
# 3237        4.8       9.0                 NaN    NaN      NaN  1.331000
# 3240        NaN       NaN                 NaN    NaN      NaN  1.430000
# 3241        NaN       NaN                 NaN    NaN      NaN  2.250000
# 3242        NaN       NaN                 NaN    NaN      NaN  1.530000
# 3243        NaN       NaN                 NaN    NaN      NaN  1.800000
# 3244        NaN       NaN                 NaN    NaN      NaN  2.230000
#
#            ganj     smack
# 3045  20.660000  0.744000
# 3084  18.583333  0.462500
# 3141  10.990000  0.498571
# 3213  12.271429  0.332857
# 3237  10.965000  0.234000
# 3240  12.800000  0.310000
# 3241  14.800000  0.530000
# 3242  11.600000  0.280000
# 3243  13.500000  0.340000
# 3244  16.100000  0.300000
#
# [10 rows x 22 columns]

# %%
nocnty2 = nocnty2.drop(index=[3240,3241,3242,3243,3244],axis = 0)
nocnty2 = nocnty2.reset_index()
nocnty2.tail()
# Out:
#     index county          state county_and_state_x  code  Deaths  Population  \
# 45   3045    NaN        Vermont                NaN   NaN     NaN         NaN
# 46   3084    NaN     Washington                NaN   NaN     NaN         NaN
# 47   3141    NaN  West Virginia                NaN   NaN     NaN         NaN
# 48   3213    NaN      Wisconsin                NaN   NaN     NaN         NaN
# 49   3237    NaN        Wyoming                NaN   NaN     NaN         NaN
#
#    Crude Rate     fips  smoking    ...     noinsurance  physicians  pollution  \
# 45        NaN  50000.0     17.0    ...             5.0       113.0        6.5
# 46        NaN  53000.0     14.0    ...             7.0        82.0        7.4
# 47        NaN  54000.0     25.0    ...             7.0        79.0        9.6
# 48        NaN  55000.0     17.0    ...             6.0        80.0        8.6
# 49        NaN  56000.0     19.0    ...            13.0        68.0        4.8
#
#     diabetes  county_and_state_y  code2  sunlight      blow       ganj  \
# 45       8.0                 NaN    NaN       NaN  2.884000  20.660000
# 46       9.0                 NaN    NaN       NaN  1.783333  18.583333
# 47      14.0                 NaN    NaN       NaN  1.287143  10.990000
# 48       9.0                 NaN    NaN       NaN  1.477143  12.271429
# 49       9.0                 NaN    NaN       NaN  1.331000  10.965000
#
#        smack
# 45  0.744000
# 46  0.462500
# 47  0.498571
# 48  0.332857
# 49  0.234000
#
# [5 rows x 23 columns]

# %%
# Need to append DC
nocnty2 = nocnty2.append(cnty_df.iloc[99,:])
nocnty2.tail()
# Out:
#      index                    county                 state  \
# 46  3084.0                       NaN            Washington
# 47  3141.0                       NaN         West Virginia
# 48  3213.0                       NaN             Wisconsin
# 49  3237.0                       NaN               Wyoming
# 99     NaN  District of Columbia, DC  District of Columbia
#
#           county_and_state_x     code  Deaths  Population Crude Rate     fips  \
# 46                       NaN      NaN     NaN         NaN        NaN  53000.0
# 47                       NaN      NaN     NaN         NaN        NaN  54000.0
# 48                       NaN      NaN     NaN         NaN        NaN  55000.0
# 49                       NaN      NaN     NaN         NaN        NaN  56000.0
# 99  District of Columbia, DC  11001.0  1752.0    681170.0      257.2      NaN
#
#     smoking    ...     noinsurance  physicians  pollution  diabetes  \
# 46     14.0    ...             7.0        82.0        7.4       9.0
# 47     25.0    ...             7.0        79.0        9.6      14.0
# 48     17.0    ...             6.0        80.0        8.6       9.0
# 49     19.0    ...            13.0        68.0        4.8       9.0
# 99      NaN    ...             NaN         NaN        NaN       NaN
#
#           county_and_state_y    code2  sunlight      blow       ganj     smack
# 46                       NaN      NaN       NaN  1.783333  18.583333  0.462500
# 47                       NaN      NaN       NaN  1.287143  10.990000  0.498571
# 48                       NaN      NaN       NaN  1.477143  12.271429  0.332857
# 49                       NaN      NaN       NaN  1.331000  10.965000  0.234000
# 99  District of Columbia, DC  11001.0  15265.36  3.425556  24.177778  0.472222
#
# [5 rows x 23 columns]

# %%
nocnty2.to_csv('Extra_Output/merged_state_data.csv')

# %% [markdown]
# Issues:
#
# * Need to included diabetes data for missing states if possible.
# * Need to fill in data at state level
# * Need to deal with 'unreliable' death rate estimates (they have a high standard deviation)
