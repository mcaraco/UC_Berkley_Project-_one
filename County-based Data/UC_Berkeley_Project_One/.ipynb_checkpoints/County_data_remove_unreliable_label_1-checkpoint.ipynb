# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import sklearn as sk
infile = 'Source_Data/merged_counties_only+.csv'

# %%
county_df = pd.read_csv(infile)
county_df.head()
# Out:
#    Unnamed: 0   county    state  county_and_state_x    code  Deaths  \
# 0           0  Autauga  Alabama  Autauga County, AL  1001.0   163.0
# 1           1  Baldwin  Alabama  Baldwin County, AL  1003.0   640.0
# 2           2  Barbour  Alabama  Barbour County, AL  1005.0    90.0
# 3           3     Bibb  Alabama     Bibb County, AL  1007.0    79.0
# 4           4   Blount  Alabama   Blount County, AL  1009.0   199.0
#
#    Population Crude Rate    fips  smoking  ...    noinsurance  physicians  \
# 0     55416.0      294.1  1001.0     19.0  ...            9.0        42.0
# 1    208563.0      306.9  1003.0     17.0  ...           11.0        73.0
# 2     25965.0      346.6  1005.0     22.0  ...           13.0        39.0
# 3     22643.0      348.9  1007.0     20.0  ...           10.0        57.0
# 4     57704.0      344.9  1009.0     20.0  ...           12.0        23.0
#
#    pollution  diabetes  county_and_state_y   code2  sunlight   blow   ganj  \
# ...

# %%
county_df['Crude Rate'] = county_df['Crude Rate'].astype('str')
county_df.head()
# Out:
#    Unnamed: 0   county    state  county_and_state_x    code  Deaths  \
# 0           0  Autauga  Alabama  Autauga County, AL  1001.0   163.0
# 1           1  Baldwin  Alabama  Baldwin County, AL  1003.0   640.0
# 2           2  Barbour  Alabama  Barbour County, AL  1005.0    90.0
# 3           3     Bibb  Alabama     Bibb County, AL  1007.0    79.0
# 4           4   Blount  Alabama   Blount County, AL  1009.0   199.0
#
#    Population Crude Rate    fips  smoking  ...    noinsurance  physicians  \
# 0     55416.0      294.1  1001.0     19.0  ...            9.0        42.0
# 1    208563.0      306.9  1003.0     17.0  ...           11.0        73.0
# 2     25965.0      346.6  1005.0     22.0  ...           13.0        39.0
# 3     22643.0      348.9  1007.0     20.0  ...           10.0        57.0
# 4     57704.0      344.9  1009.0     20.0  ...           12.0        23.0
#
#    pollution  diabetes  county_and_state_y   code2  sunlight   blow   ganj  \
# ...

# %%
county_df['Crude Rate'] = county_df['Crude Rate'].map(lambda x: x.rstrip('()Unreliab '))
county_df.iloc[69,:]
# Out:
# Unnamed: 0                                    70
# county                                Dillingham
# state                                     Alaska
# county_and_state_x    Dillingham Census Area, AK
# code                                        2070
# Deaths                                        11
# Population                                  4954
# Crude Rate                                 222.0
# fips                                        2070
# smoking                                       32
# obesity                                       39
# foodenv                                      4.7
# exercise                                      79
# noinsurance                                   21
# physicians                                   262
# pollution                                    NaN
# diabetes                                      10
# county_and_state_y                           NaN
# code2                                        NaN
# ...

# %%
county_df.iloc[65:80,:]
# Out:
#     Unnamed: 0                 county    state  \
# 65          65                 Wilcox  Alabama
# 66          66                Winston  Alabama
# 67          68              Anchorage   Alaska
# 68          69                 Bethel   Alaska
# 69          70             Dillingham   Alaska
# 70          71   Fairbanks North Star   Alaska
# 71          72                 Juneau   Alaska
# 72          73        Kenai Peninsula   Alaska
# 73          74      Ketchikan Gateway   Alaska
# 74          75      Matanuska-Susitna   Alaska
# 75          76                   Nome   Alaska
# 76          77            North Slope   Alaska
# 77          78       Northwest Arctic   Alaska
# 78          79  Prince of Wales-Hyder   Alaska
# 79          80                  Sitka   Alaska
#
#                        county_and_state_x    code  Deaths  Population  \
# 65                      Wilcox County, AL  1131.0    43.0     10986.0
# ...

# %%
county_df.to_csv('Source_Data/merged_counties_xnote.csv')
