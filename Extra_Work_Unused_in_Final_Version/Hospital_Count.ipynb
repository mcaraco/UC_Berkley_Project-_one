# %%
import pandas as pd
import numpy as np
infile = 'Extra_Raw_Data/Hospital_General_Information.csv'

# %%
hospital_df = pd.read_csv(infile)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6c50275594b0> in <module>
# ----> 1 hospital_df = pd.read_csv(infile)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
hospital_df.head()

# %%
hosp_grp = hospital_df.groupby(['State','County Name'])[['Hospital Name']].count()

# %%
hosp.grp.head()
# Out:
#                                Hospital Name
# State County Name
# AK    ANCHORAGE                            3
#       BETHEL                               1
#       DILLINGHAM                           1
#       FAIRBANKS NORTH STAR                 1
#       JUNEAU                               1
#       KENAI PENINSULA                      3
#       KETCHIKAN GATEWAY                    1
#       KODIAK ISLAND BOROUGH                1
#       MATANUSKA-SUSITNA                    1
#       NOME                                 1
#       NORTHWEST ARTIC BOROUGH              1
#       SITKA BOROUGH                        2
# AL    AUTAUGA                              1
#       BALDWIN                              3
#       BARBOUR                              1
#       BIBB                                 1
#       BLOUNT                               1
#       BULLOCK                              1
#       BUTLER                               2
# ...

# %%
# Write to new CSV
hosp_grp.to_csv('Hospital_Count_by_County.csv')
